# %% [markdown]
# 1ans:
#
# Feature selection plays an important role in anomaly detection by helping to identify the most relevant features that can effectively distinguish between normal and anomalous behavior.
#
# 2ans:
#
# Precision and Recall: These metrics are commonly used in binary classification problems, where the goal is to detect anomalies (the positive class) among a larger set of non-anomalies (the negative class). Precision measures the proportion of true positives among all predicted positives, while recall measures the proportion of true positives among all actual positives. Precision and recall can be computed as:
#
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)
#
# where TP is the number of true positives (i.e., anomalies correctly detected), FP is the number of false positives (i.e., non-anomalies incorrectly detected as anomalies), and FN is the number of false negatives (i.e., anomalies that were not detected).
#
# F1 Score: The F1 score is a measure that balances precision and recall, and is defined as the harmonic mean of the two metrics. The F1 score ranges from 0 to 1, with a higher score indicating better performance. The F1 score can be computed as:
#
# F1 Score = 2 * (Precision * Recall) / (Precision + Recall)
#
# 3ans:
#
# DBSCAN (Density-Based Spatial Clustering of Applications with Noise) is a clustering algorithm that groups together points that are closely packed together in high-density regions, while marking points that lie alone in low-density regions as noise or outliers. DBSCAN works by defining neighborhoods based on the density of points and connecting nearby neighborhoods to form clusters.
#
# 4ans:
#
# The epsilon parameter (eps) in DBSCAN determines the radius of the neighborhood around each point, which is used to determine the density of the data points. As such, the value of eps can have a significant impact on the performance of DBSCAN in detecting anomalies.
#
# If the value of eps is too small, the density of the points will be overestimated, and too many clusters will be formed. This can result in good clusters being split up, and anomalies not being identified as such. On the other hand, if the value of eps is too large, the density of the points will be underestimated, and too few clusters will be formed. This can result in multiple anomalies being grouped together as a single cluster, or some anomalies not being detected at all.
#
# 5ans:
#
# Core points: A core point is a data point that has at least the minimum number of points (min_samples) within its eps-neighborhood. Core points are typically located in high-density regions of the data and are the center of the clusters.
#
# Border points: A border point is a data point that is not a core point but lies within the eps-neighborhood of a core point. Border points are typically located on the edges of clusters and are connected to the core points.
#
# Noise points: A noise point is a data point that is not a core point or a border point. Noise points are typically located in low-density regions of the data and are not part of any cluster. Noise points are often identified as anomalies or outliers in the data.
#
# 6ans:
#
# DBSCAN  is primarily designed for clustering spatial data, but it can also be used for anomaly detection. DBSCAN detects anomalies based on the notion that anomalies have a low density of neighboring points in the feature space.
#
# The key parameters involved in the anomaly detection process with DBSCAN are:
#
# Epsilon (ε): Epsilon is a distance measure that defines the maximum distance between two points for them to be considered as neighbors. This parameter is used to determine the neighborhood of a point.
#
# Minimum points (MinPts): MinPts is the minimum number of points required in a neighborhood for a point to be considered as a core point.
#
# 7ans:
#
# The make_circles function in scikit-learn is a dataset generator that creates a binary classification problem, where the classes are defined by two concentric circles. It generates a 2D dataset that contains two classes of points, one class forming an inner circle and the other forming an outer circle.
#
# 8ans:
#
# Local outliers, also known as point anomalies, are individual data points that are considered unusual within a small neighborhood or cluster of points. They are characterized by their deviation from the surrounding points within a local region.
#
# Global outliers, also known as contextual anomalies, are data points that are unusual or unexpected within the entire dataset. They are characterized by their deviation from the overall distribution of the data.
#
# The main difference between local and global outliers is the scope of their impact. Local outliers have a limited impact on the dataset, as they only affect a small neighborhood or cluster of points. On the other hand, global outliers have a broader impact on the dataset, as they affect the overall distribution of the data.
#
# 9ans:
#
# The Local Outlier Factor (LOF) algorithm is a popular method for detecting local outliers in a dataset. It works by assigning a score to each data point based on its degree of outlier-ness within its local neighborhood. Points with a high LOF score are considered to be local outliers.
#
# 10ans:
#
# The Isolation Forest algorithm is a popular method for detecting global outliers in a dataset. It works by randomly partitioning the dataset into subsets and then isolating individual data points by creating trees from these subsets. Points that are isolated with fewer splits are considered to be global outliers.
#
# 11ans:
#
#
# Local outlier detection and global outlier detection are two different techniques for identifying outliers in a dataset, and the choice of technique depends on the problem at hand and the nature of the data. Here are some examples of real-world applications where one technique may be more appropriate than the other:
#
# Local Outlier Detection:
#
# Fraud detection: Local outlier detection can be used to identify fraudulent transactions that are not typical for a customer, such as a large transaction that is significantly different from the customer's previous transactions. This can be done by analyzing the customer's transaction history and identifying local outliers within that history.
#
# Network intrusion detection: Local outlier detection can be used to identify unusual network traffic patterns that are indicative of a potential intrusion. This can be done by analyzing the traffic flow data and identifying local outliers within that data.
#
# Global Outlier Detection:
#
# Quality control: Global outlier detection can be used to identify defective products that are significantly different from the rest of the products produced by a manufacturer. This can be done by analyzing the quality control data and identifying global outliers within that data.
# Anomaly detection in sensor networks: Global outlier detection can be used to identify anomalous behavior in sensor networks, such as a sudden drop in temperature or a spike in humidity. This can be done by analyzing the sensor data and identifying global outliers within that data.
# In summary, local outlier detection is more appropriate for detecting anomalies within a specific context or subset of data, while global outlier
